# %% [markdown]
# ***Invocamos Pandas y Matplot***

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ## EJERCICIOS DE TIPOS DE GRÁFICOS

# %% [markdown]
# *Para realizar este ejercicio, debemos importar la información del PBI per cápita de los distintos países, a lo largo de un periodo que abarca desde 1952 y 2007*

# %%
# Importamos la Información
url = "https://raw.githubusercontent.com/plotly/datasets/master/gapminder_with_codes.csv"
data = pd.read_csv(url) #Leo y lo guardo en un dataframe

#? Modificamos el tipo de dato en year para pasarlo a entero
data['year'] = data['year'].astype('int')

data.head(10)
# Out:
#        country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
# 5  Afghanistan      Asia  1977   38.438  14880372  786.113360       AFG
# 6  Afghanistan      Asia  1982   39.854  12881816  978.011439       AFG
# 7  Afghanistan      Asia  1987   40.822  13867957  852.395945       AFG
# 8  Afghanistan      Asia  1992   41.674  16317921  649.341395       AFG
# 9  Afghanistan      Asia  1997   41.763  22227415  635.341351       AFG
#
#    iso_num
# 0        4
# 1        4
# 2        4
# 3        4
# 4        4
# 5        4
# 6        4
# 7        4
# 8        4
# 9        4

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    1704 non-null   object
#  1   continent  1704 non-null   object
#  2   year       1704 non-null   int32
#  3   lifeExp    1704 non-null   float64
#  4   pop        1704 non-null   int64
#  5   gdpPercap  1704 non-null   float64
#  6   iso_alpha  1704 non-null   object
#  7   iso_num    1704 non-null   int64
# dtypes: float64(2), int32(1), int64(2), object(3)
# memory usage: 100.0+ KB

# %% [markdown]
# ## Ejercicio 1
# **1**. Elegir un año en el que desees ver la relación entre la expectativa de vida de los habitantes (columna '***lifeExp***') y el PBI per cápita de los habitantes (columna ***gdpPercap***).

# %%
year = 1982 #TODO: Cambiar por el año elegido

data_year = data[data["year"] == year] #Muestro los que cumplan la condición
data_year.head()
# Out:
#         country continent  year  lifeExp       pop    gdpPercap iso_alpha  \
# 6   Afghanistan      Asia  1982   39.854  12881816   978.011439       AFG
# 18      Albania    Europe  1982   70.420   2780097  3630.880722       ALB
# 30      Algeria    Africa  1982   61.368  20033753  5745.160213       DZA
# 42       Angola    Africa  1982   39.942   7016384  2756.953672       AGO
# 54    Argentina  Americas  1982   69.942  29341374  8997.897412       ARG
#
#     iso_num
# 6         4
# 18        8
# 30       12
# 42       24
# 54       32

# %% [markdown]
# Realizar un gráfico de puntos que muestre la relación entre la expectativa de vida (`lifeExp`) y el PBI per cápita de los habitantes (`gdpPercap`).
#
# El gráfico debe tener:
# - Título apropiado.
# - Nombre y unidades de los ejes cartesianos.
# - Marcador de tipo triangular y color "#23A763".
# - Grilla.

# %%
fig, ax = plt.subplots()

#Defino los valores de x e y
x = data_year['lifeExp']
y = data_year['gdpPercap']

ax.set_title('Expectativa de vida comparado al PBI per cápita') #Título
ax.set_xlabel('Expectativa de vida') #Título de X
ax.set_ylabel('PBI per cápita') #Título de Y

ax.grid() #Grilla
ax.scatter(x,y, color = "#23A763") #Color

plt.show()

# %% [markdown]
# ## Ejercicio 2
# Creamos un nuevo DataFrame con la información de la Argentina únicamente.

# %%
data_argentina = data[data['country'] == 'Argentina']
data_argentina.head()
# Out:
#       country continent  year  lifeExp       pop    gdpPercap iso_alpha  \
# 48  Argentina  Americas  1952   62.485  17876956  5911.315053       ARG
# 49  Argentina  Americas  1957   64.399  19610538  6856.856212       ARG
# 50  Argentina  Americas  1962   65.142  21283783  7133.166023       ARG
# 51  Argentina  Americas  1967   65.634  22934225  8052.953021       ARG
# 52  Argentina  Americas  1972   67.065  24779799  9443.038526       ARG
#
#     iso_num
# 48       32
# 49       32
# 50       32
# 51       32
# 52       32

# %% [markdown]
# Realiza un gráfico de línea que muestre el PBI per cápita de los habitantes de Argentina (`gdpPercap`) a lo largo del tiempo.
#
# El gráfico debe tener:
# - **Título apropiado**
# - **Nombre y unidades de los ejes cartesianos**
# - **Linea sólida y unidades de los ejes cartesianos**
# - **Grilla**

# %%
fig, ax = plt.subplots()

x = data_argentina['year']
y = data_argentina['gdpPercap']

#* Título del gráfico
ax.set_title('PBI per cápita de Argentina en el tiempo')

#* Título del eje x e y
ax.set_xlabel('Años')
ax.set_ylabel('PBI per cápita')


ax.grid() #Grilla
ax.plot(x, y, linestyle = 'solid')


plt.show()

# %% [markdown]
# ## Ejercicio 3
# A continuación verá todos los países de los que poseemos información. Elije uno que no sea nuestro país y luego, crea un nuevo DatFrame.

# %%
data['country'].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Angola', 'Argentina',
#        'Australia', 'Austria', 'Bahrain', 'Bangladesh', 'Belgium',
#        'Benin', 'Bolivia', 'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'Bulgaria', 'Burkina Faso', 'Burundi', 'Cambodia', 'Cameroon',
#        'Canada', 'Central African Republic', 'Chad', 'Chile', 'China',
#        'Colombia', 'Comoros', 'Congo, Dem. Rep.', 'Congo, Rep.',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Czech Republic',
#        'Denmark', 'Djibouti', 'Dominican Republic', 'Ecuador', 'Egypt',
#        'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Ethiopia',
#        'Finland', 'France', 'Gabon', 'Gambia', 'Germany', 'Ghana',
#        'Greece', 'Guatemala', 'Guinea', 'Guinea-Bissau', 'Haiti',
#        'Honduras', 'Hong Kong, China', 'Hungary', 'Iceland', 'India',
#        'Indonesia', 'Iran', 'Iraq', 'Ireland', 'Israel', 'Italy',
#        'Jamaica', 'Japan', 'Jordan', 'Kenya', 'Korea, Dem. Rep.',
# ...

# %%
country = 'France' #Todo: Cambiarlo por otro país
data_country = data[data['country'] == country]
data_country.head()
# Out:
#     country continent  year  lifeExp       pop     gdpPercap iso_alpha  \
# 528  France    Europe  1952    67.41  42459667   7029.809327       FRA
# 529  France    Europe  1957    68.93  44310863   8662.834898       FRA
# 530  France    Europe  1962    70.51  47124000  10560.485530       FRA
# 531  France    Europe  1967    71.55  49569000  12999.917660       FRA
# 532  France    Europe  1972    72.38  51732000  16107.191710       FRA
#
#      iso_num
# 528      250
# 529      250
# 530      250
# 531      250
# 532      250

# %% [markdown]
# Realiza un gráfico de línea que muestre el PBI per cápita de los habitantes de Argentina (`gdpPercap`) a lo largo del tiempo y del país escogido anteriormente.
#
# El gráfico debe tener:
# - **Título apropiado**
# - **Nombre y unidades de los ejes cartesianos**
# - **Linea sólida, espesor 2.2 y color "#30BFDE" para la curva de nuestro país.**
# - **Linea sólida, espesor 2.2 y color "#1E92E3" para la curva del nuevo país.**
# - **Referencias**
# - **Grilla**

# %%
fig, ax = plt.subplots(nrows=1, ncols=2)
fig.subplots_adjust(wspace=0.5, hspace=0.5) #Espaciado entre los gráficos

x_argentina = data_argentina['year']
y_argentina = data_argentina['gdpPercap']

ax[0].plot(x_argentina, y_argentina, label='Argentina', color='#30BFDE', linewidth = 2.2)
ax[0].legend()
ax[0].grid()
ax[0].set_title('PBI per cápita de Argentina')
ax[0].set_xlabel('Años')
ax[0].set_ylabel('PBI per cápita')

x_country = data_country['year']
y_country = data_country['gdpPercap']

ax[1].plot(x_country, y_country, label=country, color='#1E92E2', linewidth = 2.2)
ax[1].legend()
ax[1].grid()
ax[1].set_title('PBI per cápita de ' + country)
ax[1].set_xlabel('Años')
ax[1].set_ylabel('PBI per cápita')


plt.show()

# %% [markdown]
# ## Ejercicio 4
# A continuación vamos a agrupar PBI per cápita por continente.

# %%
data_continent = data[['continent', 'gdpPercap']]
data_continent = data_continent.groupby(['continent']).agg('sum')
data_continent = data_continent.reset_index() #Reseteo el index
# Out:
#   continent     gdpPercap
# 0    Africa  1.368903e+06
# 1  Americas  2.140833e+06
# 2      Asia  3.129252e+06
# 3    Europe  5.209011e+06
# 4   Oceania  4.469186e+05

# %% [markdown]
# Realiza un gráfico de torta la proporción del PBI per cápita de los habitantes de cada continente (`gdpPercap`).
#
# El gráfico debe tener:
# - **Título apropiado**
# - **Cada parte con el nombre del continente y el porcentaje redondeado a las décimas.**
# - El color de cada parte será:
#   - **América: "#30BFDE"**
#   - **Asia: "#E31E4B"**
#   - **África: "#E36F1E"**
#   - **Oceanía: "#1EE39B"**
#   - **Europa: "#1E92E3"**

# %%
#Agrego una columna nueva al dataFrame de los colores por cada continente
colores = {
    'Americas': '#30BFDE',
    'Asia': '#E31E4B',
    'Africa': '#E36F1E',
    'Oceania': '#1EE39B',
    'Europe': '#1E92E3'
}

data_continent['colors'] = data_continent['continent'].map(colores)
data_continent
# Out:
#   continent     gdpPercap   colors
# 0    Africa  1.368903e+06  #E36F1E
# 1  Americas  2.140833e+06  #30BFDE
# 2      Asia  3.129252e+06  #E31E4B
# 3    Europe  5.209011e+06  #1E92E3
# 4   Oceania  4.469186e+05  #1EE39B

# %%
fig, ax = plt.subplots()

x = data_continent['gdpPercap']
y = data_continent['continent']
colores = data_continent['colors']
ax.pie(x, labels=y, autopct='%1.1f%%', colors=colores)


plt.show()

# %% [markdown]
# ## Ejercicio 5
# Elije un continente el cual te gustaría analizar con más detalle:

# %%
continent = 'Americas' #TODO: Cambiar por otro Continente

data_one_continent = data[data["continent"] == continent]
data_one_continent = data_one_continent[['country', 'gdpPercap']]
data_one_continent = data_one_continent.groupby(['country']).agg('sum')
data_one_continent = data_one_continent.sort_values(by=['gdpPercap'])
data_one_continent = data_one_continent.reset_index()
data_one_continent
# Out:
#                 country      gdpPercap
# 0                 Haiti   19448.871474
# 1              Honduras   34012.956998
# 2    Dominican Republic   34138.276859
# 3               Bolivia   35534.745044
# 4              Paraguay   38875.281497
# 5             Nicaragua   41095.869234
# 6             Guatemala   48184.833257
# 7              Colombia   50344.115039
# 8           El Salvador   53182.159168
# 9            Costa Rica   65383.329353
# 10                 Peru   67366.129041
# 11              Ecuador   68803.497201
# 12               Panama   69057.926062
# 13               Brazil   69951.799833
# 14              Jamaica   74371.744860
# 15                 Cuba   75399.104140
# 16                Chile   80439.469765
# 17              Uruguay   85201.598108
# 18               Mexico   92689.352095
# 19  Trinidad and Tobago   94402.463357
# 20            Argentina  107466.645392
# 21            Venezuela  121062.195019
# 22          Puerto Rico  130357.971641
# ...

# %% [markdown]
# Realiza un gráfico de barras horizontales que muestre el PBI per cápita de los habitantes del continente escogido (`gdpPercap`).
#
# El gráfico debe tener:
# - Título apropiado
# - Nombre y unidades de los ejes cartesianos en caso de ser necesario
# - Nombre de los paises al lado de cada barra
# - Grilla con líneas verticales únicamente, color "#CDD7DA" y línea discontinua.

# %%
fig, ax = plt.subplots()

#set variables
pais = data_one_continent['country']
pbi = data_one_continent['gdpPercap']

ax.set_title('PBI per cápita de los habitantes de los países de ' + continent)
ax.set_xlabel('PBI per cápita')

ax.grid(axis = 'x', color = '#CDD7DA', linestyle = 'dashed')
ax.barh(pais, pbi)

plt.show()

# %% [markdown]
# ## EJERCICIOS DE GRILLAS

# %% [markdown]
# *Para estos ejercicios, vamos a crear valores aleatorios, que serán contenidos en un DataFrame que llamaremos `df`:*

# %%
np.random.seed(0)

df = pd.DataFrame(data={
    'a': np.random.randint(0, 100, 50),
    'b': np.random.randint(0, 100, 50),
    'c': np.random.randint(0, 100, 50),
    'd': np.random.randint(0, 100, 50)
})

df.head()
# Out:
#     a   b   c   d
# 0  44  75  49  80
# 1  47  55  69  32
# 2  64  28  41  54
# 3  67  34  35   0
# 4  67   0  64  38

# %% [markdown]
# ## Ejercicio 1
# **1**. Vamos a crear una grilla de 4 gráficos de línea, en la que los ejes x va a contener los valores del índice `df.index.values`, mientras que los ejes y, los valores de las columnas a, b, c y d.
#
# La figura debe tener:
# - 2 filas y 2 columas
# - Tamaño de figura de una altura de 8 y un ancho de 15.
# - Nombre de los ejes y referencia en cada gráfico
# - Grilla
# - La siguiente posición de gráficos:
#   - Los valores A en la parte superior izquierda, color `green`
#   - Los valores B en la parte superior derecha, color `red`
#   - Los valores C en la parte inferior izquierda, color `magenta`
#   - Los valores D en la parte inferior derecha, color `blue`

# %% [markdown]
# *Defino una función a la que le debo entregar los valores a graficar*

# %%
def create_easy_graph(x, y, label, ax, xlabel, ylabel, title, color):
    if color == None:
        color = "blue"
    #Si sólo haremos un gráfico, no necesito indicarle la posición
    if ax == None:
        fig, ax = plt.subplots()
    
    #Definimos el gráfico
    ax.plot(x,y, label = label, color = color)
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    ax.set_title(title)
    
    return ax

# %%
fig, ax = plt.subplots(nrows=2, ncols=2, figsize = (15, 8))
fig.subplots_adjust(wspace=0.5, hspace=0.5)

x = df.index.values
y_values_A = df['a']
y_values_B = df['b']
y_values_C = df['c']
y_values_D = df['d']


create_easy_graph(x, y_values_A, "Valores de A", ax[0][0], "Eje x", "Eje y", "Valores de A", color="green")
create_easy_graph(x, y_values_B, "Valores de A", ax[0][1], "Eje x", "Eje y", "Valores de B", color="red")
create_easy_graph(x, y_values_C, "Valores de A", ax[1][0], "Eje x", "Eje y", "Valores de C", color="magenta")
create_easy_graph(x, y_values_D, "Valores de A", ax[1][1], "Eje x", "Eje y", "Valores de D", color="blue")

ax[0][0].grid()
ax[0][1].grid()
ax[1][0].grid()
ax[1][1].grid()
plt.show()

# %% [markdown]
# ## Ejercicio 2
# **2**. Vamos a crear una grilla de 2 gráficos: uno de línea y otro de puntos, siendo los ejes x los valores del índice `df.index.values`, mientras que los ejes y, los valores de las columnas a, b, c y d.
#
# La figura debe tener:
# - 2 filas y 1 columna.
# - Tamaño de figura de una altura de 8 y un ancho de 15.
# - Título de cada gráfico.
# - Referencias.
# - Grilla.
# - La siguiente posición de gráficos:
#     - Los valores A Y B en la parte superior, en un gráfico de línea, color `green` y `red`, tipo de línea sólida y discontinua respectivamente.
#     - Los valores C Y D en la parte inferior, en un gráfico de puntos, color `magenta` y `blue`, marcador circular y triangulo invertido respectivamente.

# %%
fig, ax = plt.subplots(nrows=2, ncols=1, figsize = (15, 8))

x = df.index.values

y_values_A
y_values_B

ax[0].plot(x, y_values_A, label='Valores de A', color= 'green')
ax[0].plot(x, y_values_B, label='Valores de B', color= 'red', linestyle='dashed')
ax[0].grid()
ax[0].set_title('Gráfico de A y B')
ax[0].legend()

ax[1].scatter(x, y_values_C, label='Valores de C', color= 'magenta', marker='o')
ax[1].scatter(x, y_values_D, label='Valores de D', color= 'blue', marker='^')
ax[1].grid()
ax[1].set_title('Gráfico de C y D')
ax[1].legend()

plt.show()
